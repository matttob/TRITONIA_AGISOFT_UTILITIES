# %%
# Collect all of the patches for all of the classes created using the `patch_extractor.exe` tool
import os
import glob
import shutil, os

class_category_labels = ['A','B','C','D']
#for each label 
for category in class_category_labels:
#if this path exists 
  if os.path.isdir(r"C:\Users\test\Dropbox\PC SHARE\Code\TRITONIA_AGISOFT_LOCAL\patch_images\\" + category):
    #defining data as a list of all paths for all bmp's in MIXED_CATEGORIES
    data = glob.glob(r"C:\Users\test\Dropbox\PC SHARE\Code\TRITONIA_AGISOFT_LOCAL\patch_images\MIXED_CATEGORIES\\**\*.bmp", recursive = True)
    for f in data:
      #if label is in file path then copy f from MIXED_CATEGORIES to appropriate folder
      if '' + category + '' in f:
        shutil.copy(f, r"C:\Users\test\Dropbox\PC SHARE\Code\TRITONIA_AGISOFT_LOCAL\patch_images\\" + category)
  #if the path doesn't exist then make folders with names A, B, C, D
  else:
    os.mkdir(r"C:\Users\\test\Dropbox\PC SHARE\Code\TRITONIA_AGISOFT_LOCAL\patch_images\\" + category)
    #defining data as a list of all paths for all bmp's in MIXED_CATEGORIES
    data = glob.glob(r"C:\Users\test\Dropbox\PC SHARE\Code\TRITONIA_AGISOFT_LOCAL\patch_images\MIXED_CATEGORIES\\**\*.bmp", recursive = True)
    for f in data:
      #if label is in file path then copy f from MIXED_CATEGORIES to appropriate folder
      if '' + category + '' in f:
        shutil.copy(f, r"C:\Users\test\Dropbox\PC SHARE\Code\TRITONIA_AGISOFT_LOCAL\patch_images\\" + category)

# %%
    print((glob.glob(r"C:\Users\test\Dropbox\PC SHARE\Code\TRITONIA_AGISOFT_LOCAL\patch_images\MIXED_CATEGORIES\\**\*.bmp", recursive = True)))
# Out:
# ['C:\\Users\\test\\Dropbox\\PC SHARE\\Code\\TRITONIA_AGISOFT_LOCAL\\patch_images\\MIXED_CATEGORIES\\Frame_100_0mins_2secs_.jpg_A_0000.bmp', 'C:\\Users\\test\\Dropbox\\PC SHARE\\Code\\TRITONIA_AGISOFT_LOCAL\\patch_images\\MIXED_CATEGORIES\\Frame_100_0mins_2secs_.jpg_A_0001.bmp', 'C:\\Users\\test\\Dropbox\\PC SHARE\\Code\\TRITONIA_AGISOFT_LOCAL\\patch_images\\MIXED_CATEGORIES\\Frame_100_0mins_2secs_.jpg_A_0002.bmp', 'C:\\Users\\test\\Dropbox\\PC SHARE\\Code\\TRITONIA_AGISOFT_LOCAL\\patch_images\\MIXED_CATEGORIES\\Frame_100_0mins_2secs_.jpg_A_0003.bmp', 'C:\\Users\\test\\Dropbox\\PC SHARE\\Code\\TRITONIA_AGISOFT_LOCAL\\patch_images\\MIXED_CATEGORIES\\Frame_100_0mins_2secs_.jpg_A_0004.bmp', 'C:\\Users\\test\\Dropbox\\PC SHARE\\Code\\TRITONIA_AGISOFT_LOCAL\\patch_images\\MIXED_CATEGORIES\\Frame_100_0mins_2secs_.jpg_A_0005.bmp', 'C:\\Users\\test\\Dropbox\\PC SHARE\\Code\\TRITONIA_AGISOFT_LOCAL\\patch_images\\MIXED_CATEGORIES\\Frame_100_0mins_2secs_.jpg_A_0006.bmp', 'C:\\Users\\test\\Dropbo
# ...

# %%
print(r"C:\Users\test\Dropbox\PC SHARE\Code\TRITONIA_AGISOFT_LOCAL\patch_images\\")
# Out:
# C:\Users\test\Dropbox\PC SHARE\Code\TRITONIA_AGISOFT_LOCAL\patch_images\\
